# %%
# !source env/bin/activate

# %%
# !python3 -m scripts.prepare /project/SDS/capstones_yang/urban-tree-detection-data output.hdf5

# %%
# !python3 -m scripts.train_dice output.hdf5 logs

# %%
# !python3 -m scripts.test output.hdf5 logs
